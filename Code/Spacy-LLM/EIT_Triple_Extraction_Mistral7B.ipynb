# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from sentence_transformers import SentenceTransformer, util
import torch, json
import re
import time
from tqdm import tqdm

# %%
model_id = "mistralai/Mistral-7B-Instruct-v0.3"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,
    device_map="auto",)
# Out:
# config.json:   0%|          | 0.00/601 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.55G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %%
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,)
# Out:
# Device set to use cuda:0

# %%
with open("clean_text", "r", encoding="utf-8") as f:
    text = f.read()

text = re.sub(r"\s+", " ", text).strip()

# %%
meaningful_verbs = {
    "fund", "finance", "grant", "invest", "support", "sponsor", "award",
    "partner", "collaborate", "work", "team", "ally", "join",
    "create", "launch", "develop", "establish", "build", "initiate",
    "set up", "start", "found", "open", "introduce",
    "provide", "offer", "deliver", "train", "educate", "enable",
    "accelerate", "incubate", "scale", "facilitate", "connect",
    "select", "mentor", "coach", "coordinate", "manage",
    "operate", "organize", "implement", "run", "mobilize",
    "campaign", "advocate", "host", "innovate", "research", "pilot", "test"
}
verbs_list = ", ".join(sorted(meaningful_verbs))

# %%
model_name = "sentence-transformers/all-mpnet-base-v2"
embedder = SentenceTransformer(model_name)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
canonical_verbs = sorted(list(meaningful_verbs))
canonical_embeddings = embedder.encode(
    canonical_verbs,
    convert_to_tensor=True,
    normalize_embeddings=True
)

# %%
def normalize_verb(phrase, threshold = 0.3):

    new_embedding = embedder.encode(
        phrase,
        convert_to_tensor=True,
        normalize_embeddings=True
    )

    scores = util.cos_sim(new_embedding, canonical_embeddings)

    best_idx = torch.argmax(scores).item()
    best_verb = canonical_verbs[best_idx]
    best_score = scores[0][best_idx].item()


    if best_score < threshold:
      return None, best_score

    return best_verb, best_score

# %%
# phrase = "NetApp guided the young enterprenuers to start a tech start-up"
# best_verb, best_score = normalize_verb(phrase)

# print("Original:", phrase)
# print("Normalized:", best_verb)
# print("Similarity score:", best_score * 100)

# %%
def chunk_text(text, max_words=900):
    chunks = []
    words = text.split()
    for i in range(0, len(words), max_words):
        chunk = " ".join(words[i:i + max_words])
        chunks.append(chunk)
    return chunks

# %%
with open("clean_text", "r", encoding="utf-8") as f:
    clean_text = f.read()

chunks = chunk_text(clean_text, max_words=900)

# %%
def make_prompt(text_chunk):
    return f"""
You are an expert in extracting organizational relationship triples.

Focus ONLY on verbs related to institutional actions like:
{', '.join(canonical_verbs)}

Each triple must follow this format:
Role: [organization taking action]
Practice: [main institutional action verb — must come from the above list or its semantic equivalent]
Counterrole: [partner or recipient organization]
Context: [short quote from the text supporting the relation]

Ignore vague or non-relational verbs (e.g. "discusses", "mentions", "focuses on").

TEXT:
{text_chunk}
"""

# %%
output_path = "eit_triples_local.json"
all_triples = []

# %%
for i, chunk in enumerate(tqdm(chunks, desc="Generating triples")):
    prompt = make_prompt(chunk)

    try:
        result = pipe(
            prompt,
            max_new_tokens=400,
            temperature=0.3,
            top_p=0.9,
            return_full_text=False
        )

        generated = result[0]["generated_text"].strip()

        normalized_output = []
        for line in generated.splitlines():
            if line.lower().startswith("practice:"):
                verb_phrase = line.split(":", 1)[1].strip()
                normalized = normalize_verb(verb_phrase)
                if normalized:
                    line = f"Practice: {normalized}"
            normalized_output.append(line)

        normalized_text = "\n".join(normalized_output)

        all_triples.append({"chunk_id": i + 1, "text": normalized_text})

        if i % 3 == 0:
            with open(output_path, "w", encoding="utf-8") as f:
                json.dump(all_triples, f, ensure_ascii=False, indent=2)

        time.sleep(0.5)

    except Exception as e:
        print(f"Error in chunk {i + 1}: {e}")
        continue
# Out:
# Generating triples:   0%|          | 0/82 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples
67s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  73%|███████▎  | 60/82 [13:36<05:04, 13.86s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  74%|███████▍  | 61/82 [13:47<04:34, 13.07s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  76%|███████▌  | 62/82 [14:02<04:30, 13.52s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  77%|███████▋  | 63/82 [14:16<04:21, 13.77s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  78%|███████▊  | 64/82 [14:27<03:50, 12.79s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  79%|███████▉  | 65/82 [14:41<03:46, 13.32s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  80%|████████  | 66/82 [14:56<03:39, 13.70s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  82%|████████▏ | 67/82 [15:00<02:39, 10.65s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  83%|████████▎ | 68/82 [15:11<02:32, 10.90s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  84%|████████▍ | 69/82 [15:26<02:36, 12.04s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  85%|████████▌ | 70/82 [15:40<02:33, 12.83s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  87%|████████▋ | 71/82 [15:55<02:27, 13.39s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  88%|████████▊ | 72/82 [16:10<02:17, 13.73s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  89%|████████▉ | 73/82 [16:24<02:06, 14.02s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  90%|█████████ | 74/82 [16:39<01:53, 14.24s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  91%|█████████▏| 75/82 [16:54<01:40, 14.34s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  93%|█████████▎| 76/82 [17:08<01:26, 14.42s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  94%|█████████▍| 77/82 [17:23<01:12, 14.41s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  95%|█████████▌| 78/82 [17:37<00:57, 14.49s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  96%|█████████▋| 79/82 [17:49<00:41, 13.75s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  98%|█████████▊| 80/82 [18:04<00:28, 14.00s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples:  99%|█████████▉| 81/82 [18:19<00:14, 14.20s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generating triples: 100%|██████████| 82/82 [18:33<00:00, 13.58s/it]

# %%
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(all_triples, f, ensure_ascii=False, indent=2)

# %%
import spacy

try:
    nlp = spacy.load("en_core_web_trf")
    print("Loaded spaCy transformer model (en_core_web_trf).")
except OSError:
    nlp = spacy.load("en_core_web_sm")
    print("Transformer model not found so using en_core_web_sm instead")
# Out:
# Transformer model not found so using en_core_web_sm instead

# %%
with open("eit_triples_local.json", "r", encoding="utf-8") as f:
    raw_triples = json.load(f)

# %%
triple_pattern = re.compile(
    r"Role:\s*(.+?)\s*"
    r"Practice:\s*(.+?)\s*"
    r"Counterrole:\s*(.+?)\s*"
    r"Context:\s*(.+?)(?=Role:|$)",
    re.DOTALL | re.IGNORECASE
)

# %%
rich_triples = []

for entry in tqdm(raw_triples, desc="Enriching triples"):
    text = entry.get("text", "")
    matches = triple_pattern.findall(text)

    for role, practice, counterrole, context in matches:
        context = context.strip()

        # spacy NER on the context
        doc = nlp(context)
        ner_data = [
            {"text": ent.text, "label": ent.label_}
            for ent in doc.ents
            if ent.label_ in {"ORG", "INSTITUTION", "GPE"}
        ]

        # Clean up whitespace
        rich_triples.append({
            "role": role.strip(),
            "practice": practice.strip(),
            "counterrole": counterrole.strip(),
            "context": context,
            "ner": ner_data
        })
# Out:
# Enriching triples: 100%|██████████| 82/82 [00:03<00:00, 21.01it/s]

# %%
output_path = "eit_rich_triples.json"
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(rich_triples, f, ensure_ascii=False, indent=2)

print(f"Created {len(rich_triples)} rich triples with NER.")
print(f"Saved to {output_path}")
# Out:
# Created 386 rich triples with NER.
# Saved to eit_rich_triples.json

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("CEO of EIT Digital A central element of this partnership is the launch of the National Dual-Use Technology Accelerator")
spacy.displacy.serve(doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e59ef0a3b28a4b06bc37fa9688753a53-0" class="displacy" width="3550" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">CEO</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">EIT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Digital</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">central</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">element</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">partnership</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">launch</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">National</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Dual-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Use</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Technology</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">Accelerator</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e59ef0a3b28a4b06bc37fa9688753a53-0-0" stroke-width="2px" d="M70,352.0 C70,2.0 1800.0,2.0 1800.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e59ef0a3b28a4b06bc37fa9688753a53-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e59ef0a3b28a4b06bc37fa9688753a53-0-1" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e59ef0a3b28a4b06bc37fa9688753a53-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M210.0,354.0 L218.0,342.0 202.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e59ef0a3b28a4b06bc37fa9688753a53-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e59ef0a3b28a4b06bc37fa9688753a53-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e59ef0a3b28a4b06bc37fa9688753a53-0-3" stroke-width="2px" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e59ef0a3b28a4b06bc37fa9688753a53-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,354.0 L573.0,342.0 557.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.
